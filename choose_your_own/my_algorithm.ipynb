# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Using K-Nearest Neighbors algorithm

# %%
import my_KNN_algorithm as my_knn
from my_KNN_algorithm import features_test, labels_test

# %%
# 'n_neighbors' set to 20
pred1 = my_knn.clf.predict(features_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(labels_test, pred1)
# Out:
# 0.936

# %% [markdown]
# ### Using AdaBoost algorithm

# %%
import my_AB_algorithm as my_ab

# %%
pred2 = my_ab.clf.predict(features_test)

# %%
accuracy_score(labels_test, pred2)
# Out:
# 0.924

# %% [markdown]
# ### Using Decision Trees algorithm

# %%
import my_DT_algorithm as my_dt

# %%
# 'min_samples_split' set to 20
pred3 = my_dt.clf.predict(features_test)

# %%
accuracy_score(labels_test, pred3)
# Out:
# 0.924

# %% [markdown]
# ### Using Support Vector Machines algorithm

# %%
import my_SVM_algorithm as my_sv

# %%
pred4 = my_sv.clf.predict(features_test)

# %%
accuracy_score(labels_test, pred4)
# Out:
# 0.92

# %% [markdown]
# ### Using Naive Bayes algorithm

# %%
import my_NB_algorithm as my_nb

# %%
pred5 = my_nb.clf.predict(features_test)

# %%
accuracy_score(labels_test, pred5)
# Out:
# 0.884

# %%
from my_KNN_algorithm import features_train, labels_train

# %%
from sklearn.svm import SVC

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
svc = SVC(C=1, kernel='poly', probability=True)

# %%
ada_clf = AdaBoostClassifier(n_estimators=13, base_estimator=svc)

# %%
ada_clf.fit(features_train, labels_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#           learning_rate=1.0, n_estimators=13, random_state=None)

# %%
pred7 = ada_clf.predict(features_test)

# %%
accuracy_score(labels_test, pred7)
# Out:
# 0.9

# %% [markdown]
# ### Using Random Forest Algorithm

# %%
import my_RF_algorithm as my_rf

# %%
pred6 = my_rf.clf.predict(features_test)

# %%
accuracy_score(labels_test, pred6)
# Out:
# 0.928
