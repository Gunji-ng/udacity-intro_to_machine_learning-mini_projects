# %%
import pickle
import sys
import matplotlib.pyplot
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit

# %%
### read in data dictionary, convert to numpy array
data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "r") )
features = ["salary", "bonus"]
data = featureFormat(data_dict, features)

# %%
for point in data:
    salary = point[0]
    bonus = point[1]
    matplotlib.pyplot.scatter( salary, bonus )

matplotlib.pyplot.xlabel("salary")
matplotlib.pyplot.ylabel("bonus")
matplotlib.pyplot.show()

# %%
### your code below
len(data)
# Out:
# 95

# %%
data_dict
# Out:
# {'ALLEN PHILLIP K': {'bonus': 4175000,
#   'deferral_payments': 2869717,
#   'deferred_income': -3081055,
#   'director_fees': 'NaN',
#   'email_address': 'phillip.allen@enron.com',
#   'exercised_stock_options': 1729541,
#   'expenses': 13868,
#   'from_messages': 2195,
#   'from_poi_to_this_person': 47,
#   'from_this_person_to_poi': 65,
#   'loan_advances': 'NaN',
#   'long_term_incentive': 304805,
#   'other': 152,
#   'poi': False,
#   'restricted_stock': 126027,
#   'restricted_stock_deferred': -126027,
#   'salary': 201955,
#   'shared_receipt_with_poi': 1407,
#   'to_messages': 2902,
#   'total_payments': 4484442,
#   'total_stock_value': 1729541},
#  'BADUM JAMES P': {'bonus': 'NaN',
#   'deferral_payments': 178980,
#   'deferred_income': 'NaN',
#   'director_fees': 'NaN',
#   'email_address': 'NaN',
#   'exercised_stock_options': 257817,
#   'expenses': 3486,
#   'from_messages': 'NaN',
#   'from_poi_to_this_person': 'NaN',
#   'from_this_person_to_poi': 'NaN',
# ...

# %%
for person in data_dict.items():
    print person[0], ";  Salary:", person[1]['salary'], ";  Bonus:", person[1]['bonus']
# Out:
# METTS MARK ;  Salary: 365788 ;  Bonus: 600000
# BAXTER JOHN C ;  Salary: 267102 ;  Bonus: 1200000
# ELLIOTT STEVEN ;  Salary: 170941 ;  Bonus: 350000
# CORDES WILLIAM R ;  Salary: NaN ;  Bonus: NaN
# HANNON KEVIN P ;  Salary: 243293 ;  Bonus: 1500000
# MORDAUNT KRISTINA M ;  Salary: 267093 ;  Bonus: 325000
# MEYER ROCKFORD G ;  Salary: NaN ;  Bonus: NaN
# MCMAHON JEFFREY ;  Salary: 370448 ;  Bonus: 2600000
# HORTON STANLEY C ;  Salary: NaN ;  Bonus: NaN
# PIPER GREGORY F ;  Salary: 197091 ;  Bonus: 400000
# HUMPHREY GENE E ;  Salary: 130724 ;  Bonus: NaN
# UMANOFF ADAM S ;  Salary: 288589 ;  Bonus: 788750
# BLACHMAN JEREMY M ;  Salary: 248546 ;  Bonus: 850000
# SUNDE MARTIN ;  Salary: 257486 ;  Bonus: 700000
# GIBBS DANA R ;  Salary: NaN ;  Bonus: NaN
# LOWRY CHARLES P ;  Salary: NaN ;  Bonus: NaN
# COLWELL WESLEY ;  Salary: 288542 ;  Bonus: 1200000
# MULLER MARK S ;  Salary: 251654 ;  Bonus: 1100000
# JACKSON CHARLENE R ;  Salary: 288558 ;  Bonus: 250000
# ...

# %%
salary_dict = {}
for person in data_dict.items():
    salary_dict[person[0]]= person[1]['salary']
    
bonus_dict = {}
for person in data_dict.items():
    bonus_dict[person[0]] = person[1]['bonus']

# %%
salary_dict
# Out:
# {'ALLEN PHILLIP K': 201955,
#  'BADUM JAMES P': 'NaN',
#  'BANNANTINE JAMES M': 477,
#  'BAXTER JOHN C': 267102,
#  'BAY FRANKLIN R': 239671,
#  'BAZELIDES PHILIP J': 80818,
#  'BECK SALLY W': 231330,
#  'BELDEN TIMOTHY N': 213999,
#  'BELFER ROBERT': 'NaN',
#  'BERBERIAN DAVID': 216582,
#  'BERGSIEKER RICHARD P': 187922,
#  'BHATNAGAR SANJAY': 'NaN',
#  'BIBI PHILIPPE A': 213625,
#  'BLACHMAN JEREMY M': 248546,
#  'BLAKE JR. NORMAN P': 'NaN',
#  'BOWEN JR RAYMOND M': 278601,
#  'BROWN MICHAEL': 'NaN',
#  'BUCHANAN HAROLD G': 248017,
#  'BUTTS ROBERT H': 261516,
#  'BUY RICHARD B': 330546,
#  'CALGER CHRISTOPHER F': 240189,
#  'CARTER REBECCA C': 261809,
#  'CAUSEY RICHARD A': 415189,
#  'CHAN RONNIE': 'NaN',
#  'CHRISTODOULOU DIOMEDES': 'NaN',
#  'CLINE KENNETH W': 'NaN',
#  'COLWELL WESLEY': 288542,
#  'CORDES WILLIAM R': 'NaN',
#  'COX DAVID': 314288,
#  'CUMBERLAND MICHAEL S': 184899,
#  'DEFFNER JOSEPH M': 206121,
#  'DELAINEY DAVID W': 365163,
#  'DERRICK JR. JAMES V': 492375,
# ...

# %%
bonus_dict
# Out:
# {'ALLEN PHILLIP K': 4175000,
#  'BADUM JAMES P': 'NaN',
#  'BANNANTINE JAMES M': 'NaN',
#  'BAXTER JOHN C': 1200000,
#  'BAY FRANKLIN R': 400000,
#  'BAZELIDES PHILIP J': 'NaN',
#  'BECK SALLY W': 700000,
#  'BELDEN TIMOTHY N': 5249999,
#  'BELFER ROBERT': 'NaN',
#  'BERBERIAN DAVID': 'NaN',
#  'BERGSIEKER RICHARD P': 250000,
#  'BHATNAGAR SANJAY': 'NaN',
#  'BIBI PHILIPPE A': 1000000,
#  'BLACHMAN JEREMY M': 850000,
#  'BLAKE JR. NORMAN P': 'NaN',
#  'BOWEN JR RAYMOND M': 1350000,
#  'BROWN MICHAEL': 'NaN',
#  'BUCHANAN HAROLD G': 500000,
#  'BUTTS ROBERT H': 750000,
#  'BUY RICHARD B': 900000,
#  'CALGER CHRISTOPHER F': 1250000,
#  'CARTER REBECCA C': 300000,
#  'CAUSEY RICHARD A': 1000000,
#  'CHAN RONNIE': 'NaN',
#  'CHRISTODOULOU DIOMEDES': 'NaN',
#  'CLINE KENNETH W': 'NaN',
#  'COLWELL WESLEY': 1200000,
#  'CORDES WILLIAM R': 'NaN',
#  'COX DAVID': 800000,
#  'CUMBERLAND MICHAEL S': 325000,
#  'DEFFNER JOSEPH M': 600000,
#  'DELAINEY DAVID W': 3000000,
# ...

# %%
sorted(bonus_dict.values(), reverse=True)
# Out:
# ['NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  97343619,
#  8000000,
#  7000000,
#  5600000,
#  5249999,
#  4175000,
#  3100000,
#  3000000,
#  3000000,
#  2600000,
#  2500000,
#  2000000,
#  2000000,
#  1750000,
#  1700000,
#  1500000,
#  1500000,
#  1350000,
#  1300000,
#  1250000,
#  1200000,
#  1200000,
#  1150000,
#  1100000,
#  1100000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
# ...

# %%
sorted(salary_dict.values(), reverse=True)
# Out:
# ['NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  26704229,
#  1111258,
#  1072321,
#  1060932,
#  655037,
#  510364,
#  492375,
#  440698,
#  428780,
#  420636,
#  415189,
#  404338,
#  374125,
#  370448,
#  365788,
#  365163,
#  365038,
#  357091,
#  349487,
#  339288,
#  330546,
#  329078,
#  317543,
#  314288,
#  309946,
#  304588,
#  304110,
#  288589,
#  288558,
#  288542,
#  278601,
#  278601,
#  275101,
#  274975,
#  273746,
#  272880,
#  271442,
#  269076,
#  267102,
#  267093,
#  265214,
#  263413,
#  262788,
#  262663,
# ...

# %%
for person in data_dict.items():
    salary = person[1]['salary']
    if str(salary) == '26704229':
        print person[0]
# Out:
# TOTAL

# %%
type(data_dict.items()[0][1]['salary'])
# Out:
# int

# %%
data_dict.pop('TOTAL')
# Out:
# {'bonus': 97343619,
#  'deferral_payments': 32083396,
#  'deferred_income': -27992891,
#  'director_fees': 1398517,
#  'email_address': 'NaN',
#  'exercised_stock_options': 311764000,
#  'expenses': 5235198,
#  'from_messages': 'NaN',
#  'from_poi_to_this_person': 'NaN',
#  'from_this_person_to_poi': 'NaN',
#  'loan_advances': 83925000,
#  'long_term_incentive': 48521928,
#  'other': 42667589,
#  'poi': False,
#  'restricted_stock': 130322299,
#  'restricted_stock_deferred': -7576788,
#  'salary': 26704229,
#  'shared_receipt_with_poi': 'NaN',
#  'to_messages': 'NaN',
#  'total_payments': 309886585,
#  'total_stock_value': 434509511}

# %%
data = featureFormat(data_dict, features)

# %%
len(data)
# Out:
# 94

# %%
for point in data:
    salary = point[0]
    bonus = point[1]
    matplotlib.pyplot.scatter( salary, bonus )

matplotlib.pyplot.xlabel("salary")
matplotlib.pyplot.ylabel("bonus")
matplotlib.pyplot.show()

# %%
import pandas as pd

# %%
import numpy as np

# %%
salary_list = []
for person in data_dict.items():
    salary_list.append([person[0], person[1]['salary']])
    
bonus_list = []
for person in data_dict.items():
    bonus_list.append([person[0], person[1]['bonus']])

# %%
salary_list
# Out:
# [['METTS MARK', 365788],
#  ['BAXTER JOHN C', 267102],
#  ['ELLIOTT STEVEN', 170941],
#  ['CORDES WILLIAM R', 'NaN'],
#  ['HANNON KEVIN P', 243293],
#  ['MORDAUNT KRISTINA M', 267093],
#  ['MEYER ROCKFORD G', 'NaN'],
#  ['MCMAHON JEFFREY', 370448],
#  ['HORTON STANLEY C', 'NaN'],
#  ['PIPER GREGORY F', 197091],
#  ['HUMPHREY GENE E', 130724],
#  ['UMANOFF ADAM S', 288589],
#  ['BLACHMAN JEREMY M', 248546],
#  ['SUNDE MARTIN', 257486],
#  ['GIBBS DANA R', 'NaN'],
#  ['LOWRY CHARLES P', 'NaN'],
#  ['COLWELL WESLEY', 288542],
#  ['MULLER MARK S', 251654],
#  ['JACKSON CHARLENE R', 288558],
#  ['WESTFAHL RICHARD K', 63744],
#  ['WALTERS GARETH W', 'NaN'],
#  ['WALLS JR ROBERT H', 357091],
#  ['KITCHEN LOUISE', 271442],
#  ['CHAN RONNIE', 'NaN'],
#  ['BELFER ROBERT', 'NaN'],
#  ['SHANKMAN JEFFREY A', 304110],
#  ['WODRASKA JOHN', 'NaN'],
#  ['BERGSIEKER RICHARD P', 187922],
#  ['URQUHART JOHN A', 'NaN'],
#  ['BIBI PHILIPPE A', 213625],
#  ['RIEKER PAULA H', 249201],
# ...

# %%
bonus_list
# Out:
# [['METTS MARK', 600000],
#  ['BAXTER JOHN C', 1200000],
#  ['ELLIOTT STEVEN', 350000],
#  ['CORDES WILLIAM R', 'NaN'],
#  ['HANNON KEVIN P', 1500000],
#  ['MORDAUNT KRISTINA M', 325000],
#  ['MEYER ROCKFORD G', 'NaN'],
#  ['MCMAHON JEFFREY', 2600000],
#  ['HORTON STANLEY C', 'NaN'],
#  ['PIPER GREGORY F', 400000],
#  ['HUMPHREY GENE E', 'NaN'],
#  ['UMANOFF ADAM S', 788750],
#  ['BLACHMAN JEREMY M', 850000],
#  ['SUNDE MARTIN', 700000],
#  ['GIBBS DANA R', 'NaN'],
#  ['LOWRY CHARLES P', 'NaN'],
#  ['COLWELL WESLEY', 1200000],
#  ['MULLER MARK S', 1100000],
#  ['JACKSON CHARLENE R', 250000],
#  ['WESTFAHL RICHARD K', 'NaN'],
#  ['WALTERS GARETH W', 'NaN'],
#  ['WALLS JR ROBERT H', 850000],
#  ['KITCHEN LOUISE', 3100000],
#  ['CHAN RONNIE', 'NaN'],
#  ['BELFER ROBERT', 'NaN'],
#  ['SHANKMAN JEFFREY A', 2000000],
#  ['WODRASKA JOHN', 'NaN'],
#  ['BERGSIEKER RICHARD P', 250000],
#  ['URQUHART JOHN A', 'NaN'],
#  ['BIBI PHILIPPE A', 1000000],
#  ['RIEKER PAULA H', 700000],
# ...

# %%
salary_df = pd.DataFrame(salary_list, columns=['name', 'salary'])

# %%
salary_df.salary.replace('NaN', np.NaN, inplace=True)

# %%
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 2 columns):
# name      145 non-null object
# salary    94 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 2.3+ KB

# %%
bonus_df = pd.DataFrame(bonus_list, columns=['name', 'bonus'])
bonus_df
# Out:
#                      name    bonus
# 0              METTS MARK   600000
# 1           BAXTER JOHN C  1200000
# 2          ELLIOTT STEVEN   350000
# 3        CORDES WILLIAM R      NaN
# 4          HANNON KEVIN P  1500000
# 5     MORDAUNT KRISTINA M   325000
# 6        MEYER ROCKFORD G      NaN
# 7         MCMAHON JEFFREY  2600000
# 8        HORTON STANLEY C      NaN
# 9         PIPER GREGORY F   400000
# 10        HUMPHREY GENE E      NaN
# 11         UMANOFF ADAM S   788750
# 12      BLACHMAN JEREMY M   850000
# 13           SUNDE MARTIN   700000
# 14           GIBBS DANA R      NaN
# 15        LOWRY CHARLES P      NaN
# 16         COLWELL WESLEY  1200000
# 17          MULLER MARK S  1100000
# 18     JACKSON CHARLENE R   250000
# 19     WESTFAHL RICHARD K      NaN
# 20       WALTERS GARETH W      NaN
# 21      WALLS JR ROBERT H   850000
# 22         KITCHEN LOUISE  3100000
# 23            CHAN RONNIE      NaN
# 24          BELFER ROBERT      NaN
# 25     SHANKMAN JEFFREY A  2000000
# ...

# %%
bonus_df.bonus.replace('NaN', np.NaN, inplace=True)

# %%
bonus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 2 columns):
# name     145 non-null object
# bonus    81 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 2.3+ KB

# %%
salary_bonus_df = salary_df.merge(bonus_df, on='name')

# %%
salary_bonus_df.dropna()
# Out:
#                      name     salary      bonus
# 0              METTS MARK   365788.0   600000.0
# 1           BAXTER JOHN C   267102.0  1200000.0
# 2          ELLIOTT STEVEN   170941.0   350000.0
# 4          HANNON KEVIN P   243293.0  1500000.0
# 5     MORDAUNT KRISTINA M   267093.0   325000.0
# 7         MCMAHON JEFFREY   370448.0  2600000.0
# 9         PIPER GREGORY F   197091.0   400000.0
# 11         UMANOFF ADAM S   288589.0   788750.0
# 12      BLACHMAN JEREMY M   248546.0   850000.0
# 13           SUNDE MARTIN   257486.0   700000.0
# 16         COLWELL WESLEY   288542.0  1200000.0
# 17          MULLER MARK S   251654.0  1100000.0
# 18     JACKSON CHARLENE R   288558.0   250000.0
# 21      WALLS JR ROBERT H   357091.0   850000.0
# 22         KITCHEN LOUISE   271442.0  3100000.0
# 25     SHANKMAN JEFFREY A   304110.0  2000000.0
# 27   BERGSIEKER RICHARD P   187922.0   250000.0
# 29        BIBI PHILIPPE A   213625.0  1000000.0
# 30         RIEKER PAULA H   249201.0   700000.0
# ...

# %%
salary_bonus_df[salary_bonus_df['salary'] > 1000000]
# Out:
#                    name     salary      bonus
# 65        LAY KENNETH L  1072321.0  7000000.0
# 95   SKILLING JEFFREY K  1111258.0  5600000.0
# 128      FREVERT MARK A  1060932.0  2000000.0

# %%
salary_bonus_df
# Out:
#                      name     salary      bonus
# 0              METTS MARK   365788.0   600000.0
# 1           BAXTER JOHN C   267102.0  1200000.0
# 2          ELLIOTT STEVEN   170941.0   350000.0
# 3        CORDES WILLIAM R        NaN        NaN
# 4          HANNON KEVIN P   243293.0  1500000.0
# 5     MORDAUNT KRISTINA M   267093.0   325000.0
# 6        MEYER ROCKFORD G        NaN        NaN
# 7         MCMAHON JEFFREY   370448.0  2600000.0
# 8        HORTON STANLEY C        NaN        NaN
# 9         PIPER GREGORY F   197091.0   400000.0
# 10        HUMPHREY GENE E   130724.0        NaN
# 11         UMANOFF ADAM S   288589.0   788750.0
# 12      BLACHMAN JEREMY M   248546.0   850000.0
# 13           SUNDE MARTIN   257486.0   700000.0
# 14           GIBBS DANA R        NaN        NaN
# 15        LOWRY CHARLES P        NaN        NaN
# 16         COLWELL WESLEY   288542.0  1200000.0
# 17          MULLER MARK S   251654.0  1100000.0
# 18     JACKSON CHARLENE R   288558.0   250000.0
# ...

# %%
salary_bonus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 3 columns):
# name      145 non-null object
# salary    94 non-null float64
# bonus     81 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 4.5+ KB

# %%
non_null_salary_bonus_df = salary_bonus_df.dropna()

# %%
non_null_salary_bonus_df
# Out:
#                      name     salary      bonus
# 0              METTS MARK   365788.0   600000.0
# 1           BAXTER JOHN C   267102.0  1200000.0
# 2          ELLIOTT STEVEN   170941.0   350000.0
# 4          HANNON KEVIN P   243293.0  1500000.0
# 5     MORDAUNT KRISTINA M   267093.0   325000.0
# 7         MCMAHON JEFFREY   370448.0  2600000.0
# 9         PIPER GREGORY F   197091.0   400000.0
# 11         UMANOFF ADAM S   288589.0   788750.0
# 12      BLACHMAN JEREMY M   248546.0   850000.0
# 13           SUNDE MARTIN   257486.0   700000.0
# 16         COLWELL WESLEY   288542.0  1200000.0
# 17          MULLER MARK S   251654.0  1100000.0
# 18     JACKSON CHARLENE R   288558.0   250000.0
# 21      WALLS JR ROBERT H   357091.0   850000.0
# 22         KITCHEN LOUISE   271442.0  3100000.0
# 25     SHANKMAN JEFFREY A   304110.0  2000000.0
# 27   BERGSIEKER RICHARD P   187922.0   250000.0
# 29        BIBI PHILIPPE A   213625.0  1000000.0
# 30         RIEKER PAULA H   249201.0   700000.0
# ...
